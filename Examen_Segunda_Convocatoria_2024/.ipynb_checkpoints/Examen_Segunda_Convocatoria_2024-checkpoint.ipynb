# %% [markdown]
# <h1 style = "font-size:3rem;color:orange">Examen segunda convocatoria 2024</h1>

# %% [markdown]
# #### Librerías

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %% [markdown]
# # 1 - 1.25 pt
# Dado una lista de valores, cree un diccionario cuya clave sea el dato de la lista y el valor sea el resto de la división entre 6. No se deben incluir en el diccionario los valores cuyo resto es igual a cero.

# %%
def dct_items(lst):
    return {item: item % 6 for item in lst if item % 6 != 0}

# %%
ls_val = [30, 23, 7, 39, 55,  5, -4]
dc_res = dct_items(ls_val)  # This calls your function
dc_solucion = {23: 5, 7: 1, 39: 3, 55: 1, 5: 5, -4: 2}
assert(dc_res == dc_solucion), "Solución incorrecta"

# %% [markdown]
# # 2 - 1.25 pt
# Realice con numpy:
# - Una matriz 4x2 (A) y un vector 4x1 (b) con valores aleatorios
# - Calcule la inversa de la multiplicación A traspuesta por la misma matriz, multiplíquelo por la matriz traspuesta de A y el vector b: $x =(A^{T}  A)^{-1} A^{T}b$
# - Multiplique $x$ por un array de dos valores aleatorios.

# %%
A = np.random.randint(0, 10, size=(4, 2))
b = np.random.randint(0, 10, size=(4, 1))

print(A)
print(b)

x = np.dot(np.invert(np.dot(np.transpose(A), A)), np.dot(np.transpose(A), b))

print()
print(x)
# Out:
# [[5 9]
#  [7 9]
#  [1 4]
#  [8 6]]
# [[0]
#  [7]
#  [6]
#  [4]]
#
# [[-30051]
#  [-37872]]

# %% [markdown]
# # 3 - 1.25 pt
#
# Se pide crear un generador que recorra una lista dada y, que en cada llamada, devuelva la media de los valores contiguos y el valor central definido por la posición del índice de dicha lista. Es decir, dada la lista [12, 3, 9, 3, 6], el generador devolverá en la primera iteración la media de 12 y 3 dando como resultado 7.5. En la segunda iteración será 12, 3 y 9, resultando 8. El último valor que devolverá será 3 y 6, resultando 4.5.

# %%
def generador_medias(lst):
    position = 0
    while position < len(lst):
        if position == 0:
            yield np.round((lst[position] + lst[position + 1]) / 2, 1)
        elif position == len(lst) - 1:
            yield np.round((lst[position - 1] + lst[position]) / 2, 1)
        else:
            yield np.round((lst[position - 1] + lst[position] + lst[position + 1]) / 3, 1)
        position += 1

# %%
ls_num = [12, 3, 9, 3, 6]
gen = generador_medias(ls_num)
ls_res = []
ls_solucion = [7.5, 8.0, 5.0, 6.0, 4.5]
for i in gen:
    ls_res.append(i)
assert (ls_res==ls_solucion), "Solución incorrecta"

# %% [markdown]
# # 4 - 1.25 pt
#
# Se pide crear una función que reciba un array de NumPy y devuelva otro en el cual estén marcados como True los elementos duplicados (a partir de la segunda ocurrencia), y como False los no repetidos o las primeras ocurrencias de los duplicados.

# %%
def find_duplicates(lst):
    output_lst = []
    dct = []
    for item in lst:
        if item not in dct:
            output_lst.append(False)
            dct.append(item)
        else:
            output_lst.append(True)
    
    return output_lst

# %%
numbers = np.array([4, 4, 4, 3, 8, 1, 9, 6, 1, 5, 9, 4, 0, 2])
expected_output = np.array([False, True, True, False, False, False, False, False, True, False, True, True, False, False])
output = find_duplicates(numbers)   # This calls your function find_duplicates
assert(np.array_equal(expected_output, output))  # This will fail if the result is not as expected

# %% [markdown]
# # 5 - 5 pt
#
# - Adjunto al notebook se puede encontrar un fichero 'ine_paro_exam.csv' que contiene datos del INE referentes al paro en España. Las columnas son las siguientes:
#   - Sexo, los datos de esa fila se refieren a hombres, mujeres o ambos sexos
#   - Provincias, los datos de esa fila son totales para todo el pais, o de alguna provincia en particular
#   - Tasas, que tipo de tasa representa el valor de la fila, es de actividad, paro o empleo.
#   - Periodo, a que periodo de tiempo aplica el dato, año y trimestre
#   - Total, el dato de la tasa
# - Se pide lo siguiente:
#   - Cargar los datos en un dataframe de Pandas.
#   - Realice un análisis descriptivo de los datos y haga un recuento de datos por cada valor único de la columna "Tasas".
#   - ¿Cuantos valores nulos hay por columna? Eliminar las filas que tienen nulo en la columna "Total" y muestre el número de columnas tras esta operación.
#   - Obtener la media de la tasa de paro por trimestre, en la provincia de Zaragoza y para ambos sexos.
#   - Representar una figura con tres gráficas con tres diferentes tasas el total nacional y ambos sexos, de manera que en cada subfigura se represente la evolución por trimestre de cada año (cada año se considera una linea con un color diferente). Se adjunta al examen imagen de muestra de lo solicitado
#
# ![tasasportrimestre.png](tasasportrimestre.png)

# %%
# Cargar los datos en un dataframe de pandas
data = pd.read_csv("ine_paro_exam.csv", sep='|')
display(data)

# Análisis descriptivo de los datos y recuento de datos de la columna "Tasas"
display(data.describe())
# display(data.describe(include='all'))
display(data.info())

print("\nRecuento de datos de la columna Tasas:\n{}".format(data['Tasas'].value_counts()))

# Valores nulos por columna. Eliminar filas con nulo en la columna "Total" y representar los datos.
print("\nValores nulos por columna:\n{}".format(data.isnull().sum()))

mask = data['Total'].notnull()
data = data[mask]
print("\nValores nulos por columna:\n{}".format(data.isnull().sum()))
print()
display(data)
# data.dropna(subset=['Total'], inplace=True)
# print("\nValores nulos por columna:\n{}".format(data.isnull().sum()))

# Media de la tasa de paro por trimestre, en Zaragoza y para ambos sexos.
zaragoza_paro = data[(data['Provincias'] == '50 Zaragoza') & (data['Tasas'] == 'Tasa de paro de la población') & (data['Sexo'] == 'Ambos sexos')]
display(zaragoza_paro)

zaragoza_paro['Trimestre'] = zaragoza_paro['Periodo'].str.extract(r'T(\d)')
zaragoza_paro['Trimestre'] = pd.to_numeric(zaragoza_paro['Trimestre'])
display(zaragoza_paro)

medias_trimestre = []
for trimestre in range(1, 5):
    mask = zaragoza_paro['Trimestre'] == trimestre
    data_trimestre = zaragoza_paro[mask]
    media = data_trimestre['Total'].mean()
    medias_trimestre.append(media)

print("Media de la tasa de paro por trimestre en la provincia de Zaragoza y para ambos sexos:")
index = 0
while index < len(medias_trimestre):
    print(f"Trimestre {index + 1}: {medias_trimestre[index]:.2f}")
    index += 1

# Representación gráfica.
mask = data['Provincias'] == 'Total Nacional'
data4 = data[mask]
mask = data4['Sexo'] == 'Ambos sexos'
data4 = data4[mask]

mask = data4['Tasas'] == 'Tasa de actividad'
data4_actividad = data4[mask]
mask = data4['Tasas'] == 'Tasa de paro de la población'
data4_paro = data4[mask]
mask = data4['Tasas'] == 'Tasa de empleo de la población'
data4_empleo = data4[mask]

fig, axes = plt.subplots(3, 1, figsize=(7, 15))

data4_actividad['Año'] = data4_actividad['Periodo'].str[:4]
data4_actividad['Trimestre'] = data4_actividad['Periodo'].str[-2:]

data4_actividad_clean = data4_actividad[['Total', 'Año', 'Trimestre']]

for year in data4_actividad_clean['Año'].unique():
    data_year = data4_actividad_clean[data4_actividad_clean['Año'] == str(year)]
    data_year = data_year.groupby('Trimestre').mean(numeric_only=True)
    axes[0].plot(data_year)

axes[0].set_title('Tasa de actividad')
axes[0].set_ylabel('Total')

data4_paro['Año'] = data4_paro['Periodo'].str[:4]
data4_paro['Trimestre'] = data4_paro['Periodo'].str[-2:]

data4_paro_clean = data4_paro[['Total', 'Año', 'Trimestre']]

for year in data4_paro_clean['Año'].unique():
    data_year = data4_paro_clean[data4_paro_clean['Año'] == str(year)]
    data_year = data_year.groupby('Trimestre').mean(numeric_only=True)
    axes[1].plot(data_year)

axes[1].set_title('Tasa de paro de la población')
axes[1].set_ylabel('Total')

data4_empleo['Año'] = data4_empleo['Periodo'].str[:4]
data4_empleo['Trimestre'] = data4_empleo['Periodo'].str[-2:]

data4_empleo_clean = data4_empleo[['Total', 'Año', 'Trimestre']]

for year in data4_empleo_clean['Año'].unique():
    data_year = data4_empleo_clean[data4_empleo_clean['Año'] == str(year)]
    data_year = data_year.groupby('Trimestre').mean(numeric_only=True)
    axes[2].plot(data_year)

axes[2].set_title('Tasa de empleo de la población')
axes[2].set_xlabel('Trimestre')
axes[2].set_ylabel('Total')

plt.show()
# Out:
#               Sexo      Provincias                           Tasas Periodo  \
# 0      Ambos sexos  Total Nacional               Tasa de actividad  2023T1
# 1      Ambos sexos  Total Nacional               Tasa de actividad  2022T4
# 2      Ambos sexos  Total Nacional               Tasa de actividad  2022T3
# 3      Ambos sexos  Total Nacional               Tasa de actividad  2022T2
# 4      Ambos sexos  Total Nacional               Tasa de actividad  2022T1
# ...            ...             ...                             ...     ...
# 40540      Mujeres      52 Melilla  Tasa de empleo de la población  2003T1
# 40541      Mujeres      52 Melilla  Tasa de empleo de la población  2002T4
# 40542      Mujeres      52 Melilla  Tasa de empleo de la población  2002T3
# 40543      Mujeres      52 Melilla  Tasa de empleo de la población  2002T2
# 40544      Mujeres      52 Melilla  Tasa de empleo de la población  2002T1
#
#        Total
# 0      58.55
# 1      58.52
# 2      58.86
# ...
